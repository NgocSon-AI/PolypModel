# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/PolypModel'
# Out:
# /content/drive/MyDrive/PolypModel

# %%
# !pip install tensorboardX
# !pip install timm==0.6.11
# !pip install wandb
# !pip install einops
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.7/548.7 kB 18.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.13
#     Uninstalling timm-1.0.13:
#       Successfully uninstalled timm-1.0.13
# ...

# %%
! python train.py
# Out:
# Downloading: "https://huggingface.co/sail/dl/resolve/main/caformer/caformer_s18_in21ft1k.pth" to /root/.cache/torch/hub/checkpoints/caformer_s18_in21ft1k.pth
# 100% 101M/101M [00:04<00:00, 23.4MB/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# [ Wed Jan 15 01:35:52 2025 ] # Parameters: 52522590
# [ Wed Jan 15 01:35:52 2025 ] Training epoch: 1
# 100%|███| 72/72 [01:45<00:00,  1.46s/it]
# [ Wed Jan 15 01:37:55 2025 ] 	Mean training loss: 0.1194.  Mean dice_score: 65.29%.   Mean iou_score: 50.28%
# [ Wed Jan 15 01:37:55 2025 ] 	Time consumption: [Data]34%, [Network]66%
# ...

# %%
! pip install --upgrade timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.3/53.3 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 32.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: timm
#     Found existing installation: timm 0.6.11
#     Uninstalling timm-0.6.11:
#       Successfully uninstalled timm-0.6.11
# ...

# %%
! python predict.py
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Downloading: "https://huggingface.co/sail/dl/resolve/main/caformer/caformer_s18_in21ft1k.pth" to /root/.cache/torch/hub/checkpoints/caformer_s18_in21ft1k.pth
# 100% 101M/101M [00:00<00:00, 106MB/s]
# ...
